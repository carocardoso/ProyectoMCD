# %% [markdown]
# # 3. Modelado

# %%
# !pip install bertopic
# Out:
# Requirement already satisfied: bertopic in /usr/local/lib/python3.12/dist-packages (0.17.4)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.12/dist-packages (from bertopic) (0.8.40)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (0.5.9.post2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (2.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from bertopic) (5.1.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.12/dist-packages (from bertopic) (4.67.1)
# Requirement already satisfied: llvmlite>0.36.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (0.43.0)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from hdbscan>=0.8.29->bertopic) (1.16.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from hdbscan>=0.8.29->bertopic) (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=4.7.0->bertopic) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=4.7.0->bertopic) (25.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.57.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.9.0+cu126)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.36.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.15.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.11.12)

# %%
# !pip install cohere
# Out:
# Requirement already satisfied: cohere in /usr/local/lib/python3.12/dist-packages (5.20.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /usr/local/lib/python3.12/dist-packages (from cohere) (1.12.1)
# Requirement already satisfied: httpx>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from cohere) (0.28.1)
# Requirement already satisfied: httpx-sse==0.4.0 in /usr/local/lib/python3.12/dist-packages (from cohere) (0.4.0)
# Requirement already satisfied: pydantic>=1.9.2 in /usr/local/lib/python3.12/dist-packages (from cohere) (2.12.3)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /usr/local/lib/python3.12/dist-packages (from cohere) (2.41.4)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cohere) (2.32.4)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from cohere) (0.22.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cohere) (2.32.4.20250913)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from cohere) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.21.2->cohere) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.21.2->cohere) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.21.2->cohere) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.21.2->cohere) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.21.2->cohere) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.9.2->cohere) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.9.2->cohere) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (2.5.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers<1,>=0.15->cohere) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (1.2.0)

# %%
from bertopic import BERTopic
import pandas as pd

from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer

from hdbscan import HDBSCAN
from umap import UMAP

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import cohere
from bertopic.representation import Cohere

API_KEY = 'kR.....I'
co = cohere.Client(API_KEY)

# %%
# agregar palabras consideradas vacías y que no están en stopwords
words = ['así', 'ej','si','través']
stopwords = nltk.corpus.stopwords.words('spanish')
stopwords.extend(words)

# %% [markdown]
# ## 3.1 Carga de datos

# %%
# Cargar el archivo CSV preparado en la etapa anterior en un DataFrame de pandas

df = pd.read_csv('https://github.com/carocardoso/dataset_tesis/raw/refs/heads/main/datos_carr_sel_prepro.csv', sep=";", encoding='latin1')

#ruta_csv = "../datos/datos_carr_sel_prepro.csv"
#df = pd.read_csv(ruta_csv, encoding='latin1', sep=";")

df.head()
# Out:
#       id  anio                                             titulo  \
# 0  69877  2021  Intervenciones que lleva adelante el psicólogo...
# 1  69993  2021  La gestión estratégica de Recursos Humanos en ...
# 2  69991  2021  El impacto del Covid-19 y la reorganización la...
# 3  64368  2018  El bienestar psicológico en las mujeres conduc...
# 4  75264  2023  Las características de la comunicación mediáti...
#
#                                              resumen  \
# 0  el presente informe, que se realiza como traba...
# 1  el presente trabajo de investigación, toma com...
# 2  la vida laboral no está exenta de sucesos estr...
# 3  el presente estudio tiene como objetivo, estab...
# 4  el objetivo del presente proyecto es analizar ...
#
#                                         texto_limpio  \
# 0  intervenciones que lleva adelante el psicólogo...
# 1  la gestión estratégica de recursos humanos en ...
# 2  el impacto del covid   y la reorganización lab...
# 3  el bienestar psicológico en las mujeres conduc...
# 4  las características de la comunicación mediáti...
#
#                                            texto_tok  \
# 0  intervenciones lleva adelante psicólogo practi...
# 1  gestión estratégica recursos humanos ente regu...
# 2  impacto covid reorganización laboral estrés la...
# 3  bienestar psicológico mujeres conductoras tran...
# 4  características comunicación mediática formas ...
#
#                     facultad                                  carrera  \
# 0           Artes y Ciencias               Licenciatura en Psicología
# 1  Economía y Administración         Licenciatura en Recursos Humanos
# 2  Economía y Administración         Licenciatura en Recursos Humanos
# 3           Artes y Ciencias               Licenciatura en Psicología
# 4           Artes y Ciencias  Licenciatura en Comunicaciones Sociales
#
#    descargas  vistas                                                url  \
# 0        143      40  https://bibliotecas.ucasal.edu.ar/opac_css/ind...
# 1        143     108  https://bibliotecas.ucasal.edu.ar/opac_css/ind...
# 2        156     115  https://bibliotecas.ucasal.edu.ar/opac_css/ind...
# 3        349     161  https://bibliotecas.ucasal.edu.ar/opac_css/ind...
# 4         38      25  https://bibliotecas.ucasal.edu.ar/opac_css/ind...
#
#                                                  pdf  \
# 0  https://bibliotecas.ucasal.edu.ar/opac_css/698...
# 1  https://bibliotecas.ucasal.edu.ar/opac_css/699...
# 2  https://bibliotecas.ucasal.edu.ar/opac_css/699...
# 3  https://bibliotecas.ucasal.edu.ar/opac_css/643...
# 4  https://bibliotecas.ucasal.edu.ar/opac_css/752...
#
#                                         resumen_orig palabras
# 0  El presente informe, que se realiza como traba...       78
# 1  El presente trabajo de investigación, toma com...       79
# 2  La vida laboral no está exenta de sucesos estr...       84
# 3  El presente estudio tiene como objetivo, estab...       87
# 4  El objetivo del presente proyecto es analizar ...       88

# %% [markdown]
# ## 3.2 Preparación de datos
# Esto se hizo en la etapa anterior pero se afina el preprocesamiento
# Se probó el modelado "limpiando los textos" y con el campo sin procesar

# %%
# al generar el csv se agregó como salto de linea '_x000D_'. Se elimina aqui
df['texto_limpio'] = df['texto_limpio'].str.replace('_x000D_', '')
df['texto_limpio'] = df['texto_limpio'].str.replace('nº bº', '')
df['texto_limpio'] = df['texto_limpio'].str.replace('n° b°', '')
df['texto_limpio'] = df['texto_limpio'].str.replace('nº', '')
df['texto_limpio'] = df['texto_limpio'].str.replace('n°', '')
df['texto_limpio'] = df['texto_limpio'].str.replace('bº', '')
df['texto_limpio'] = df['texto_limpio'].str.replace('b°', '')

# %% [markdown]
# ## 3.3 Entrenamiento

# %%
# # agregar palabras consideradas vacías y que no están en stopwords
# words = ['así', 'ej','si','través']
# stopwords = nltk.corpus.stopwords.words('spanish')
# stopwords.extend(words)

# %% [markdown]
# Crear una función personalizada para generar etiquetas con Command-R

# %%
def generar_labels(topic_model, docs_per_topic, active_topic_ids, carrera, nr_words=10):
    """
    Genera etiquetas para cada tópico usando Cohere Command-R.

    Args:
        topic_model: Modelo BERTopic entrenado.
        docs_per_topic: Documentos agrupados por tópico.
        active_topic_ids: Lista de IDs de tópicos activos en el modelo.
        nr_words: Número de palabras clave a incluir en el prompt.

    Returns:
        dict: Diccionario {topic_id: "etiqueta_generada"}
    """
    lista=[]
    labels = {}

    for topic_id in active_topic_ids:
        if topic_id == -1:  # Tópico de outliers
            labels[topic_id] = "Documentos diversos"
            continue

        # Obtener palabras clave del tópico
        keywords = topic_model.get_topic(topic_id)[:nr_words]
        keyword_list = [word for word, _ in keywords]

        # Obtener los documentos representativos para este tópico
        representative_docs_for_topic = docs_per_topic.get(topic_id, [])

        palclave= ', '.join(keyword_list)
        docu= chr(10).join([f'- {doc[:200]}...' for doc in representative_docs_for_topic[:5]])
        lista.append([palclave, docu])


        # Crear prompt para Command-R
        prompt = f"""
    Eres un experto en análisis temático. Genera un título descriptivo (5 a 7 palabras)
    para un grupo de documentos académicos basado en:

    PALABRAS CLAVE: {', '.join(keyword_list)}

    FRAGMENTOS DE DOCUMENTOS:
    {chr(10).join([f'- {doc[:200]}...' for doc in representative_docs_for_topic[:5]])}

    CONTEXTO:
    Los documentos son resúmenes de trabajos finales de la carrera universitaria: {carrera}.

    INSTRUCCIONES:
    1. El título debe capturar la esencia temática
    2. Usar terminología académica apropiada
    3. Formato: sustantivo + adjetivo/modificador
    4. Escrito en idioma español

    TÍTULO SUGERIDO:
    """

        # Llamada a la API de Cohere
        try:
            # Llamada a la NUEVA Chat API
            response = co.chat(
                model='command-r-plus-08-2024',  # o 'command-r-plus-08-2024'
                message=prompt,
                temperature=0.3,
                max_tokens=30
            )

            # Extraer texto de la respuesta
            label = response.text.strip()
            # Limpieza básica
            label = label.replace('"', '').replace("'", "").strip()
            labels[topic_id] = label

        except Exception as e:
            print(f"Error generando etiqueta para tópico {topic_id}: {e}")
            # Fallback a palabras clave
            labels[topic_id] = " - ".join(keyword_list[:3])
    print(lista)
    return labels

# %%
## CAMBIAR AQUI
def config_model(cantidad_docs):
  if cantidad_docs >200:
   min_cluster_size = 3
   n_neighbors = 15
   outliers = 40

  elif cantidad_docs >=110:
    min_cluster_size = 2
    n_neighbors = 5
    outliers = 20
  else:
    min_cluster_size = 3
    n_neighbors = 15
    outliers = 20
  # Ajustar min_cluster_size para fomentar más clusters, con un mínimo de 2 tópicos.
  # min_cluster_size = max(3, int(round(cantidad_docs * 0.01, 0))) # e.g., 1% of docs, with a minimum of 2
  # n_neighbors = max(15, int(round(cantidad_docs * 0.15,0)))  # Cantidad de vecinos en el cluster, proporción según cant de docs 10%. DEFAULT 15
  # outliers = min(20, int(round(cantidad_docs * 0.15,0)))  # Cantidad máx de docs sin clasificar 15%
  print(f'Cantidad de documentos: {cantidad_docs}.  min_cluster_size: {min_cluster_size}, n_neighbors: {n_neighbors}, outliers: {outliers}')

  return min_cluster_size, n_neighbors, outliers

# %%
from bertopic.representation import MaximalMarginalRelevance

#Mejorar la representación predeterminada. CountVectorizer elimina palabras vacías e ignora las palabras poco frecuentes.
#Considera los tokens con una o dos palabras (ngramas).
vectorizer_model = CountVectorizer(stop_words=stopwords, ngram_range=(1, 2))

#Obtener embeddings
embedding_model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

  #Para reducir esta redundancia y mejorar la diversidad de palabras clave, el algoritmo MMR considera la similitud de las palabras clave o frases clave con el documento,
    #así la selección de palabras clave maximiza su diversidad dentro del documento.
representation_model = MaximalMarginalRelevance(diversity=0.5)
#   λ = 1.0: Relevancia pura (búsqueda vectorial regular)
# λ = 0,5: Enfoque equilibrado
# λ = 0,0: Diversidad pura

# función para entrenar el modelo a partir de un conjunto de documentos
def train_model(docs, carrera, df_carr):
  #configuración inicial
  min_cluster_size, n_neighbors, outliers = config_model(len(docs))

  #embeddings
  embeddings = embedding_model.encode(docs, show_progress_bar=True)

 # HDBSCAN: min_cluster_size controla la cantidad de temas que se crearán. Un número grande generará menos temas y un número pequeño generará más temas.
  hdbscan_model = HDBSCAN(min_cluster_size=min_cluster_size, metric='euclidean', cluster_selection_epsilon=0.05, min_samples=10, prediction_data=True)
 # cluster_selection_epsilon=0.05,  # ↓ Menor valor para evitar unir clusters cercanos
 # cluster_selection_method='eom', , prediction_data=True
 #min_samples=3,             # ↑ Mayor valor para clusters más densos

    # UMAP reduce la dimensionalidad
  umap_model = UMAP(n_neighbors=n_neighbors, min_dist=0.2, metric='cosine', random_state=42)
    #n_neighbors=15 n_neighbors
    #n_components=10 ↑ Mayor dimensionalidad para separar clusters


  # Definición del modelo
  topic_model = BERTopic(
      # Pipeline models
      embedding_model=embedding_model,
      umap_model=umap_model,
      hdbscan_model=hdbscan_model,
      vectorizer_model=vectorizer_model,
      representation_model=representation_model,

      nr_topics=5,  # FORZAR max de tópicos (intenta reducir a 5 si hay más)

      calculate_probabilities=True,
      language="multilingual",
      # Hyperparameters
      #top_n_words=10,
      verbose=True
    )

# Train model
  topics, probs = topic_model.fit_transform(docs, embeddings=embeddings)

  print(f" Tópico -1 ...Cant:  {topics.count(-1)}")

  # # si hay muchos outliers, ajustar modelo
  if (topics.count(-1) > outliers):
     print(f"  Reajustando modelo ...outliers: {topics.count(-1)}")
     # reducción de outliers
     new_topics = topic_model.reduce_outliers(docs, topics, probabilities=probs, strategy="probabilities") #strategy xq en topic_model se calculó las probab

  #   #topic_model.update_topics(docs, topics=new_topics)  #toma stopwords
  #   #topic_model.update_topics(docs, vectorizer_model=vectorizer_model, embedding_model=embedding_model)
  #   #topic_model.update_topics(docs, vectorizer_model=vectorizer_model)
     #topic_model.update_topics(docs, topics=new_topics,vectorizer_model=vectorizer_model)
     topic_model.update_topics(docs, topics=new_topics,vectorizer_model=vectorizer_model, representation_model=representation_model)

  #Generar etiquetas personalizadas
  docs_per_topic = topic_model.get_representative_docs()

  # Get the active topic IDs from the model's final state after reduction
  active_topic_ids = topic_model.get_topic_info()['Topic'].tolist()

  custom_labels = generar_labels(topic_model, docs_per_topic, active_topic_ids, carrera)

  # Asignar las etiquetas al modelo
  topic_model.set_topic_labels(custom_labels)

  df_carr['topic'] = topics

  # Extract the probability of the assigned topic from the 2D 'probs' array
  assigned_probabilities = []
  for doc_idx, topic_id in enumerate(topics):
      if topic_id == -1:
          assigned_probabilities.append(0.0)  # Assign 0 for outlier topic, or consider a different approach
      else:
          # Ensure topic_id maps to a valid column index in probs
          if topic_id < probs.shape[1]:
              assigned_probabilities.append(probs[doc_idx, topic_id])
          else:
              assigned_probabilities.append(0.0) # Fallback if topic_id is out of bounds

  df_carr['topic_probability'] = assigned_probabilities

  # Add Representative_document column
  representative_docs_set = set()
  for topic_id, docs_list in docs_per_topic.items():
      for doc_text in docs_list:
          representative_docs_set.add((topic_id, doc_text))

  df_carr['Representative_document'] = df_carr.apply(
      lambda row: (row['topic'], row['texto_limpio']) in representative_docs_set,
      axis=1
  )

  # Print the number of valid topics found
  # num_valid_topics = len(topic_model.get_topic_info()) - 1
  # print(f"  Número de tópicos válidos encontrados: {num_valid_topics}")

  return topic_model , df_carr

# %% [markdown]
# ## 3.4 Obtener modelos para cada carrera

# %%
# Obtener lista de carreras seleccionadas
carr_sel = df['carrera'].unique()
carr_sel
# Out:
# array(['Licenciatura en Psicología', 'Licenciatura en Recursos Humanos',
#        'Licenciatura en Comunicaciones Sociales'], dtype=object)

# %%
#guardar los modelos para evaluar y mostrar gráficos
lista_modelos = pd.DataFrame(columns=['carrera', 'modelo'])

topic_freq_list = []
topic_docs_list = []

for carr in carr_sel:
    df_carr = df[df['carrera']==carr]

    sel_docs = df_carr['texto_limpio'].tolist() # Convert Series to a list of strings
    print('\n'+carr+ '. Cantidad de docs: '+ str(len(sel_docs)))

    # ENTRENAMIENTO con docs de la carrera seleccionada
    #topic_model = train_model(sel_docs, carr)
    topic_model, tdoc = train_model(sel_docs, carr, df_carr)

    #tópicos frecuentes
    freq = topic_model.get_topic_info()
    freq['carrera'] = carr  # agregar una columna con la carrera

    #agregar a la lista de tópicos frecuentes
    topic_freq_list.append(freq) # Append DataFrame to the list

    # #asignar a cada documento el tópico que le corresponda, using the filtered documents
    # tdoc = topic_model.get_document_info(sel_docs)
    # tdoc['carrera'] = carr
    # tdoc['anio'] = df_carr['anio'] #.values  #df['anio']  #agregar columna año

    topic_docs_list.append(tdoc)

    # guardar el modelo (reducido) para usar en dashboard
    nbre_modelo="model_" + carr.replace(" ","_")

    #topic_model.save(nbre_modelo)
    topic_model.save(nbre_modelo, serialization="safetensors", save_ctfidf=True, save_embedding_model=embedding_model)
    lista_modelos = pd.concat([lista_modelos, pd.DataFrame({'carrera': [carr], 'modelo': nbre_modelo})]) #para descarga de zip

# Concatenate all DataFrames in the list after the loop
topic_freq = pd.concat(topic_freq_list, ignore_index=True) if topic_freq_list else pd.DataFrame()
topic_docs = pd.concat(topic_docs_list, ignore_index=True) if topic_docs_list else pd.DataFrame()
# Out:
# Licenciatura en Psicología. Cantidad de docs: 204
# Cantidad de documentos: 204.  min_cluster_size: 3, n_neighbors: 15, outliers: 40
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# 2025-12-11 18:33:05,669 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-12-11 18:33:06,150 - BERTopic - Dimensionality - Completed ✓
# 2025-12-11 18:33:06,151 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-12-11 18:33:06,169 - BERTopic - Cluster - Completed ✓
# 2025-12-11 18:33:06,170 - BERTopic - Representation - Extracting topics using c-TF-IDF for topic reduction.
# 2025-12-11 18:33:06,352 - BERTopic - Representation - Completed ✓
# 2025-12-11 18:33:06,356 - BERTopic - Topic reduction - Reducing number of topics
# 2025-12-11 18:33:06,357 - BERTopic - Topic reduction - Number of topics (5) is equal or higher than the clustered topics(4).
# 2025-12-11 18:33:06,358 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-12-11 18:33:07,969 - BERTopic - Representation - Completed ✓
#  Tópico -1 ...Cant:  35
# [['mujeres, participantes, violencia género, provincia salta, entrevistas, presente investigación, capital, víctimas, relación, juegos', '- prisión domiciliaria en mujeres : violencias y vulnerabilidad. el presente trabajo de investigación abordará acerca de las violencias y vulnerabilidades que anteceden al contexto carcelario, vivenciad...\n- creencias irracionales y violencia de género : una mirada desde la terapia racional emotiva conductual sobre las mujeres víctimas de violencia de género en la pareja. la presente investigación surge c...\n- las representaciones sociales del personal de la policía de la provincia de salta sobre las mujeres que denuncian violencia de género en el año  . la presente investigación se enmarcó dentro del campo...'], ['salud, trabajo, ciudad salta, entrevistas, participantes, análisis, psicología, cualitativo, hospital, jóvenes', '- representaciones sociales de los profesionales de salud mental sobre las modalidades de atención psicoterapéuticas implementadas durante el aislamiento social, preventivo y obligatorio, y su incidenci...\n- inclusión laboral de los usuarios del hospital de salud mental dr. miguel ragone, en la ciudad de salta, en el año  . el derecho al trabajo es un derecho humano fundamental, presente tanto en la conve...\n- representaciones sociales sobre personas con padecimientos mentales en agentes de salud del primer nivel de atención : aportes para pensar prácticas novedosas en salud mental. esta investigación indag...'], ['poder judicial, poder, servicio psicología, pasantía académica, forense, mediación, rol psicólogo, psicólogo jurídico, judicial provincia, distrito centro', '- el rol del psicólogo jurídico forense en la evaluación de postulantes a guarda con fines de adopción : pasantía académica en la secretaría tutelar del poder judicial de salta. el presente trabajo, enm...\n- el rol del psicólogo jurídico forense en causas de abuso sexual en el servicio de psicología área penal víctimas en el distrito centro del poder judicial de la provincia de salta, durante el año  . el...\n- prácticas psicológicas periciales jurídico forenses en casos de violencias de género en el servicio de psicología del poder judicial de la provincia de salta distrito centro en el año  . la presente p...']]
#
# Licenciatura en Recursos Humanos. Cantidad de docs: 110
# Cantidad de documentos: 110.  min_cluster_size: 2, n_neighbors: 5, outliers: 20
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2025-12-11 18:33:26,736 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-12-11 18:33:26,897 - BERTopic - Dimensionality - Completed ✓
# 2025-12-11 18:33:26,898 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-12-11 18:33:26,913 - BERTopic - Cluster - Completed ✓
# 2025-12-11 18:33:26,914 - BERTopic - Representation - Extracting topics using c-TF-IDF for topic reduction.
# 2025-12-11 18:33:26,998 - BERTopic - Representation - Completed ✓
# 2025-12-11 18:33:26,999 - BERTopic - Topic reduction - Reducing number of topics
# 2025-12-11 18:33:27,001 - BERTopic - Topic reduction - Number of topics (5) is equal or higher than the clustered topics(5).
# 2025-12-11 18:33:27,004 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-12-11 18:33:28,754 - BERTopic - Representation - Completed ✓
# 2025-12-11 18:33:28,811 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#  Tópico -1 ...Cant:  67
#   Reajustando modelo ...outliers: 67
# [['recursos humanos, empresa, proceso, personal, desarrollo, reclutamiento selección, salta, herramientas, empleados, horas', '- el desarrollo de carrera de los jóvenes no profesionales a través de la técnica de mentoring en mkd s.a.. el presente trabajo analiza el desarrollo profesional de los operadores telefónicos a través d...\n- gestión estrategica de recursos humanos, desarrollo e implementación de los procesos correspondientes a los subsistemas de integración y organización en la empresa colorearg durante el año  . los subt...\n- proceso de reclutamiento y selección de asesores comerciales en una empresa privada de comercialización de vehículos de la provincia de jujuy. cualquier organización, independientemente de su tamaño, ...'], ['investigación, recursos humanos, gestión, empleados, relación, salud, desempeño, social, teletrabajo, estrés', '- la rotación y las políticas de retención de personal en el gimnasio xx período  . este trabajo final de graduación aborda el tema de la relación entre la rotación externa y las políticas de retención ...\n- las tipologías relacionales del acoso laboral en propietarios y empleados de organizaciones del rubro comercial, en la ciudad de salta, durante el año  . el acoso laboral o mobbing es un problema que ...\n- las condiciones de trabajo que afectan la calidad de vida de los oficiales superiores jefes de la policía de la provincia de salta. el presente trabajo de investigación denominado las condiciones de t...'], ['clima, clima organizacional, clima laboral, productividad, evaluación desempeño, empleados, satisfacción laboral, recursos humanos, desempeño laboral, cultura', '- influencia de la satisfacción laboral en la productividad de la empresa nutrirec biofarma ,  . en los últimos años, la gestión de recursos humanos y la administración organizacional fue adaptándose a ...\n- la evaluación de desempeño en cafe martínez y su incidencia en el nivel de desempeño de los trabajadores, en la ciudad de salta durante el año  . en el presente trabajo se indaga la importancia del us...'], ['empleados, habilidades, motivación, liderazgo, calidad, diferencias, recursos humanos, organizaciones, objetivos, capital', '- los procesos de capacitaciones del capital humano de la facultad de artes y ciencias de la universidad católica de salta. david ulrich   , en su libro recursos humanos champions , sostiene que la capa...\n- incentivos no monetarios, motivación y desempeño laboral. el modo de incentivar al personal es uno de los aspectos centrales de la cultura de una empresa. en este contexto, la motivación es un factor ...\n- soft skills y desempeño laboral de los trabajadores del área de rrhh de la empresa natur s.a.. las soft skills, habilidades blandas en español, son determinantes para que las personas puedan desempeña...']]
#
# Licenciatura en Comunicaciones Sociales. Cantidad de docs: 103
# Cantidad de documentos: 103.  min_cluster_size: 3, n_neighbors: 15, outliers: 20
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2025-12-11 18:33:49,985 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-12-11 18:33:50,212 - BERTopic - Dimensionality - Completed ✓
# 2025-12-11 18:33:50,213 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-12-11 18:33:50,226 - BERTopic - Cluster - Completed ✓
# 2025-12-11 18:33:50,227 - BERTopic - Representation - Extracting topics using c-TF-IDF for topic reduction.
# 2025-12-11 18:33:50,318 - BERTopic - Representation - Completed ✓
# 2025-12-11 18:33:50,319 - BERTopic - Topic reduction - Reducing number of topics
# 2025-12-11 18:33:50,321 - BERTopic - Topic reduction - Number of topics (5) is equal or higher than the clustered topics(5).
# 2025-12-11 18:33:50,322 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-12-11 18:33:52,155 - BERTopic - Representation - Completed ✓
# 2025-12-11 18:33:52,216 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#  Tópico -1 ...Cant:  66
#   Reajustando modelo ...outliers: 66
# [['redes sociales, comunicación, trabajo, periodismo, sociedad, medios comunicación, periodistas, cobertura, provincia, juicio', '- las manifestaciones de periodismo social en tucumán: el caso de el tucumano. el periodismo social busca ser transversal a toda producción de la prensa. tiene como objeto jerarquizar la información del...\n- la participación ciudadana en los medios de comunicación de salta y sus plataformas virtuales. la presente investigación consiste en un estudio de casos realizado a ocho medios masivos de comunicación...\n- comunicación pública del gobierno municipal de la ciudad de salta : el plan de medios con foco en redes sociales durante el período  . el propósito de este trabajo es investigar y describir de qué man...'], ['comunicación, investigación, público, cambios, ciudad salta, canciones, identidad, estrategias, social, videojuegos', '- el cine grotesco. la presente investigación aborda el cuerpo humano y los patrones que el arte elabora para distinguir los cuerpos bellos de los cuerpos ominosos. bajo este paradigma emerge la figura ...\n- plan de comunicación para el relanzamiento de un negocio de indumentaria de alta costura en la ciudad de salta. la finalidad del siguiente proyecto de investigación es analizar el reposicionamiento de...\n- comunicación alternativa: los murales de walpaq y julien guinet en la ciudad de salta : año  . la presente investigación se enmarca en el ámbito de la comunicación alternativa y se centra en el fenóme...'], ['influencers, redes sociales, estrategias, instagram, mercado, usuarios, branding, blogs, mujeres, red social', '- la gestión de redes sociales para la campaña de lanzamiento de complementa, un emprendimiento de accesorios en la ciudad de salta. año  . la presente tesis consiste en investigar cuáles son las estrat...\n- influencers en la red social instagram. el tema de la presente investigación se introduce en el contexto de una empresa de la ciudad de salta que recurre como estrategia de comunicación a influencers ...\n- el uso de redes sociales de comunicación para el emprendimiento localinda deco durante el periodo mayo   abril   y su impacto en el público objetivo. este trabajo de investigación describe y explora e...'], ['análisis, trabajo, estrategias, institucional, ciudad salta, campaña, estrategias comunicación, salud, social, alumnos', '- la comunicación en la gestión de responsabilidad social corporativa del grupo asegurador la segunda en la provincia de salta, durante el año  . la presente investigación identifica y propone la estrat...\n- la comunicación interinstitucional : una necesidad para el buen desarrollo institucional. estudio de caso: salta solidaria en red. se presenta la presente tesis de grado en la facultad de artes y cien...\n- caracterización de la gestión de comunicación interna en el nivel secundario del colegio milagroso niño jesús de praga y su impacto en el público interno en marzo de  . en la actualidad, cuando la com...']]

# %%
descarga=1  #descargar cada carpeta que contiene los archivos de modelos como un .zip
if descarga==1:
  # Code added to zip and download the model folders
  from google.colab import files
  import os

  print("\nDescargando modelos...")
  for index, row in lista_modelos.iterrows():
      model_dir = row['modelo']
      zip_filename = f"{model_dir}.zip"
      if os.path.isdir(model_dir):
          print(f"Zipping {model_dir}...")
          # !zip -r $zip_filename $model_dir
          print(f"Downloading {zip_filename}...")
          files.download(zip_filename)
      else:
          print(f"Directory {model_dir} not found. Skipping download.")
# Out:
# Descargando modelos...
# Zipping model_Licenciatura_en_Psicología...
# updating: model_Licenciatura_en_Psicología/ (stored 0%)
# updating: model_Licenciatura_en_Psicología/topics.json (deflated 75%)
# updating: model_Licenciatura_en_Psicología/config.json (deflated 43%)
# updating: model_Licenciatura_en_Psicología/ctfidf_config.json (deflated 73%)
# updating: model_Licenciatura_en_Psicología/ctfidf.safetensors (deflated 84%)
# updating: model_Licenciatura_en_Psicología/topic_embeddings.safetensors (deflated 6%)
# Downloading model_Licenciatura_en_Psicología.zip...
# Zipping model_Licenciatura_en_Recursos_Humanos...
# updating: model_Licenciatura_en_Recursos_Humanos/ (stored 0%)
# updating: model_Licenciatura_en_Recursos_Humanos/topics.json (deflated 73%)
# updating: model_Licenciatura_en_Recursos_Humanos/config.json (deflated 43%)
# updating: model_Licenciatura_en_Recursos_Humanos/ctfidf_config.json (deflated 73%)
# updating: model_Licenciatura_en_Recursos_Humanos/ctfidf.safetensors (deflated 84%)
# updating: model_Licenciatura_en_Recursos_Humanos/topic_embeddings.safetensors (deflated 7%)
# Downloading model_Licenciatura_en_Recursos_Humanos.zip...
# Zipping model_Licenciatura_en_Comunicaciones_Sociales...
# updating: model_Licenciatura_en_Comunicaciones_Sociales/ (stored 0%)
# updating: model_Licenciatura_en_Comunicaciones_Sociales/topics.json (deflated 73%)
# updating: model_Licenciatura_en_Comunicaciones_Sociales/config.json (deflated 43%)
# updating: model_Licenciatura_en_Comunicaciones_Sociales/ctfidf_config.json (deflated 73%)
# updating: model_Licenciatura_en_Comunicaciones_Sociales/ctfidf.safetensors (deflated 85%)
# updating: model_Licenciatura_en_Comunicaciones_Sociales/topic_embeddings.safetensors (deflated 7%)
# Downloading model_Licenciatura_en_Comunicaciones_Sociales.zip...

# %%
topic_freq
# Out:
#     Topic  Count                                               Name  \
# 0      -1     35        -1_trabajo_investigación_niños_adolescentes
# 1       0     25  0_mujeres_participantes_violencia género_provi...
# 2       1    136           1_salud_trabajo_ciudad salta_entrevistas
# 3       2      8  2_poder judicial_poder_servicio psicología_pas...
# 4       0     46        0_recursos humanos_empresa_proceso_personal
# 5       1     27  1_investigación_recursos humanos_gestión_emple...
# 6       2     12  2_clima_clima organizacional_clima laboral_pro...
# 7       3     25       3_empleados_habilidades_motivación_liderazgo
# 8       0     20   0_redes sociales_comunicación_trabajo_periodismo
# 9       1     22       1_comunicación_investigación_público_cambios
# 10      2     15  2_influencers_redes sociales_estrategias_insta...
# 11      3     46       3_análisis_trabajo_estrategias_institucional
#
#                                            CustomName  \
# 0                                 Documentos diversos
# 1   Violencia de Género: Estudio de Casos en Mujer...
# 2   Representaciones Psicosociales en la Inclusión...
# 3   Prácticas Forenses en Psicología Jurídica: Eva...
# 4   Gestión Estratégica de Recursos Humanos en Emp...
# 5   Gestión de Recursos Humanos: Salud, Estrés y R...
# 6   Satisfacción Laboral y su Impacto en el Desemp...
# 7   Desarrollo de Habilidades y Motivación en el C...
# 8   Comunicación Social: Periodismo y Participació...
# 9   Comunicación Social: Identidad y Estrategias e...
# 10  Estrategias de Influencia Digital: Emprendimie...
# 11  Comunicación Estratégica: Gestión Instituciona...
#
#                                        Representation  \
# 0   [trabajo, investigación, niños, adolescentes, ...
# 1   [mujeres, participantes, violencia género, pro...
# 2   [salud, trabajo, ciudad salta, entrevistas, pa...
# 3   [poder judicial, poder, servicio psicología, p...
# 4   [recursos humanos, empresa, proceso, personal,...
# 5   [investigación, recursos humanos, gestión, emp...
# 6   [clima, clima organizacional, clima laboral, p...
# 7   [empleados, habilidades, motivación, liderazgo...
# 8   [redes sociales, comunicación, trabajo, period...
# 9   [comunicación, investigación, público, cambios...
# 10  [influencers, redes sociales, estrategias, ins...
# 11  [análisis, trabajo, estrategias, institucional...
#
#                                   Representative_Docs  \
# 0   [las representaciones sociales sobre los jóven...
# 1   [prisión domiciliaria en mujeres : violencias ...
# 2   [representaciones sociales de los profesionale...
# 3   [el rol del psicólogo jurídico forense en la e...
# 4   [el desarrollo de carrera de los jóvenes no pr...
# 5   [la rotación y las políticas de retención de p...
# 6   [influencia de la satisfacción laboral en la p...
# 7   [los procesos de capacitaciones del capital hu...
# 8   [las manifestaciones de periodismo social en t...
# 9   [el cine grotesco. la presente investigación a...
# 10  [la gestión de redes sociales para la campaña ...
# 11  [la comunicación en la gestión de responsabili...
#
#                                     carrera
# 0                Licenciatura en Psicología
# 1                Licenciatura en Psicología
# 2                Licenciatura en Psicología
# 3                Licenciatura en Psicología
# 4          Licenciatura en Recursos Humanos
# 5          Licenciatura en Recursos Humanos
# 6          Licenciatura en Recursos Humanos
# 7          Licenciatura en Recursos Humanos
# 8   Licenciatura en Comunicaciones Sociales
# 9   Licenciatura en Comunicaciones Sociales
# 10  Licenciatura en Comunicaciones Sociales
# 11  Licenciatura en Comunicaciones Sociales

# %%
#ponerr todos los nombres de columnas en minúsculas para facilitar el proceso/visualización posterior
#topic_freq.columns = topic_freq.columns.str.lower()
#topic_docs.columns = topic_docs.columns.str.lower()

# descargar los datos para mostrar
topic_freq.to_csv('topic_freq.csv', index=False, encoding='latin1', sep=";" , quoting=1)
topic_docs.to_csv('topic_docs.csv', index=False, encoding='latin1', sep=";" , quoting=1)

# %% [markdown]
# ## 3.5 Mostrar resultados de cada carrera seleccionada

# %%
def mostrar_resultados_por_carrera(carrera, df, model):
  print(f"Resultados del modelado de tópicos - {carrera}")
  print("-"*(len(carrera)+40))

  df_carrera = df[df['carrera']==carrera]

    # Imprimo resulados
  print("\nTópicos")
  print("-----------")
  freq = model.get_topic_info()
  display(freq)
  print()

  print("\nTópicos y probabilidades")
  print("------------------------")
  # mostrar todos los tópicos cons las keys
  df_topics = pd.DataFrame()   #auxiliar
  all_topics = model.get_topics()
  for topico in all_topics:
    df_topic_words_temp = pd.DataFrame(model.get_topic(topico))
    df_topic_words_temp.columns = [f'Topic{topico}_word', f'Topic{topico}_prob']
    df_topics = pd.concat([df_topics, df_topic_words_temp], axis=1)

  display(df_topics)

  print('\nRanking de palabras en cada tópico')
  print('----------------------------------')
 # barchart de ranking de palabras por tópico (se inclyen 5 keys por tópico por claridad)
  fig1 = model.visualize_barchart(top_n_topics=len(model.get_topics()), n_words=5)
  fig1.show()

  if (len(all_topics)-1) > 2:
    print('\nDistribución de clusters')
    print('------------------------')
    # interactivo distribución/distancia entre tópicos
    try:
      fig2 = model.visualize_topics()
      fig2.show()
    except TypeError as e:
      print(f"  Error al visualizar la distribución de clusters (visualize_topics): {e}")
      print("  Esto puede ocurrir con un número muy pequeño de tópicos. Se omitirá esta visualización.")

  print('\nJerarquía de clusters')
  print('---------------------')

  # jerarquia de clusters
  fig3 = model.visualize_hierarchy(top_n_topics=50) # Commented out due to ValueError with few topics
  fig3.show()

  print('\nEvolución de tópicos por años')
  print('---------------------------')
  # Evolución de tópicos por años
  timestamps = df_carrera['anio'].tolist()
  topics_over_time = model.topics_over_time(df_carrera['texto_limpio'], timestamps, nr_bins=20)
  fig4 =  model.visualize_topics_over_time(topics_over_time, top_n_topics=10)
  fig4.show()

  #Visualizacion de documentos
  print('\nVisualización de documentos')
  print('---------------------------')

  embeddings = embedding_model.encode(df_carrera['texto_limpio'], show_progress_bar=True)

  # Run the visualization with the original embeddings
  topic_model.visualize_documents(df_carrera['texto_limpio'], embeddings=embeddings)

  # Reduce dimensionality of embeddings, this step is optional but much faster to perform iteratively:
  reduced_embeddings = UMAP(n_neighbors=10, n_components=2, min_dist=0.0, metric='cosine').fit_transform(embeddings)
  topic_model.visualize_documents(df_carrera['texto_limpio'], reduced_embeddings=reduced_embeddings)

# %%
#cargo cada modelo para ver los resultados

elto_lista_mod = lista_modelos.iloc[0]
model_name = elto_lista_mod['modelo']
carrera =elto_lista_mod['carrera']

df_datos = df[df['carrera'] == elto_lista_mod['carrera']]

# cargar el modelo
modelo = BERTopic.load(model_name, embedding_model)

# mostrar resultados en forma visual
mostrar_resultados_por_carrera(carrera, df_datos, modelo)
# Out:
# Resultados del modelado de tópicos - Licenciatura en Psicología
# ------------------------------------------------------------------
#
# Tópicos
# -----------
#    Topic  Count                                               Name  \
# 0     -1     35        -1_trabajo_investigación_niños_adolescentes
# 1      0     25  0_mujeres_participantes_violencia género_provi...
# 2      1    136           1_salud_trabajo_ciudad salta_entrevistas
# 3      2      8  2_poder judicial_poder_servicio psicología_pas...
#
#                                           CustomName  \
# 0                                Documentos diversos
# 1  Violencia de Género: Estudio de Casos en Mujer...
# 2  Representaciones Psicosociales en la Inclusión...
# 3  Prácticas Forenses en Psicología Jurídica: Eva...
#
#                                       Representation  Representative_Docs
# 0  [trabajo, investigación, niños, adolescentes, ...                  NaN
# 1  [mujeres, participantes, violencia género, pro...                  NaN
# 2  [salud, trabajo, ciudad salta, entrevistas, pa...                  NaN
# 3  [poder judicial, poder, servicio psicología, p...                  NaN
# Tópicos y probabilidades
# ------------------------
#               Topic-1_word  Topic-1_prob             Topic0_word  Topic0_prob  \
# 0                  trabajo      0.022830                 mujeres     0.053792
# 1            investigación      0.022438           participantes     0.020109
# 2                    niños      0.012813        violencia género     0.019169
# 3             adolescentes      0.011044         provincia salta     0.013867
# 4                    nivel      0.010032             entrevistas     0.013778
# 5            rol psicólogo      0.009372  presente investigación     0.013149
# 6                    rugby      0.009193                 capital     0.012734
# 7                   riesgo      0.009044                víctimas     0.012251
# 8                violencia      0.008659                relación     0.012026
# 9  licenciatura psicología      0.008630                  juegos     0.011964
#
#      Topic1_word  Topic1_prob          Topic2_word  Topic2_prob
# 0          salud     0.012951       poder judicial     0.067791
# 1        trabajo     0.011455                poder     0.060263
# 2   ciudad salta     0.010789  servicio psicología     0.046331
# 3    entrevistas     0.010294   pasantía académica     0.042358
# 4  participantes     0.010216              forense     0.041338
# 5       análisis     0.010026            mediación     0.039503
# 6     psicología     0.009930        rol psicólogo     0.038336
# 7    cualitativo     0.009753   psicólogo jurídico     0.038152
# 8       hospital     0.009007   judicial provincia     0.032174
# 9        jóvenes     0.008227      distrito centro     0.030028
# Ranking de palabras en cada tópico
# ----------------------------------
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="16a4eb78-7308-4eb4-accf-ab24262a5013" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16a4eb78-7308-4eb4-accf-ab24262a5013")) {                    Plotly.newPlot(                        "16a4eb78-7308-4eb4-accf-ab24262a5013",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.013778355742008834,0.013866701381381845,0.01916900762510527,0.02010912929816937,0.0537921608257922],"y":["entrevistas  ","provincia salta  ","violencia género  ","participantes  ","mujeres  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.010215713111362478,0.010293519756447853,0.010789260102101905,0.011454859740724972,0.012951345039544851],"y":["participantes  ","entrevistas  ","ciudad salta  ","trabajo  ","salud  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.041338243255938836,0.04235831302063542,0.046331376555286206,0.060263057067955164,0.06779123125208322],"y":["forense  ","pasantía académica  ","servicio psicología  ","poder  ","poder judicial  "],"type":"bar","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666 ...
# Distribución de clusters
# ------------------------
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5c378714-0c5e-4a50-81cb-b0f501f55b4a" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c378714-0c5e-4a50-81cb-b0f501f55b4a")) {                    Plotly.newPlot(                        "5c378714-0c5e-4a50-81cb-b0f501f55b4a",                        [{"customdata":[[0,"mujeres | participantes | violencia género | provincia salta | entrevistas",25],[1,"salud | trabajo | ciudad salta | entrevistas | participantes",136],[2,"poder judicial | poder | servicio psicología | pasantía académica | forense",8]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[25,136,8],"sizemode":"area","sizeref":0.085,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[46.00291,45.399647,44.691036],"xaxis":"x","y":[-44.6011,-45.41154,-44.7853],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#4828 ...
# Jerarquía de clusters
# ---------------------
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="60a9b2a2-7d6f-4397-ae97-aceced9299dd" class="plotly-graph-div" style="height:245px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60a9b2a2-7d6f-4397-ae97-aceced9299dd")) {                    Plotly.newPlot(                        "60a9b2a2-7d6f-4397-ae97-aceced9299dd",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.532949044457743,0.532949044457743,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8492920575014448,0.8492920575014448,0.532949044457743],"xaxis":"x","y":[-5.0,-5.0,-20.0,-20.0],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":245,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["2_poder judicial_poder_serv...","1_salud_trabajo_ciudad salta","0_mujeres_participantes_vio..."],"tickvals":[-5.0,-15.0,-25.0],"type":"linear","zeroline":false,"range":[-30.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222 ...
# Evolución de tópicos por años
# ---------------------------
# 10it [00:00, 13.34it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9c4526a7-fcd6-40de-a7df-da57fd951508" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c4526a7-fcd6-40de-a7df-da57fd951508")) {                    Plotly.newPlot(                        "9c4526a7-fcd6-40de-a7df-da57fd951508",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: acto, homicida, pareja, relación, modelo","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: mujeres, violencia, amor, juegos, género","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: mujeres, amorosa, relación, posición subjetiva, subjetiva","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: violencia, mujeres, género, investigación, pareja","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: mujeres, violencia, víctimas violencia, violencia familiar, víctimas","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: mujeres, violencia, género, salta, investigación","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: mujeres, investigación, salta, violencia, femenino"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_mujeres_participantes_violencia género...","x":[2014.991,2017.7,2018.6,2019.95,2020.85,2021.75,2022.65],"y":[1,4,1,5,2,6,6],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: enfermedad, niño, vida, adolescentes, familia","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: investigación, salta, síndrome, carrera, burnout","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: sé, población, investigación, carcelaria, iii","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: investigación, salta, análisis, trabajo, datos","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: investigación, salta, año, jóvenes, hospital","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: investigación, salud, nivel, salta, año","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: investigación, año, salta, estudio, sociales","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: investigación, salud, conocer, salta, trabajo","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: investigación, salta, año, salud, ciudad","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: valores, valores actitud, hospital, año, investigación"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"1_salud_trabajo_ciudad salta_entrevistas","x":[2014.991,2015.9,2016.8,2017.7,2018.6,2019.95,2020.85,2021.75,2022.65,2023.55],"y":[3,4,6,29,14,16,19,14,27,4],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: judicial, mediación, psicólogo, procesos, mediación judicial","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: judicial, pasantía, familiar género, poder judicial, violencia familiar","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: judicial, jurídico, poder judicial, psicología, psicólogo","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: judicial, poder judicial, psicología, poder, jurídico"],"marker":{"color":"#009E73"},"mode":"lines","name":"2_poder judicial_poder_servicio psicolog...","x":[2017.7,2020.85,2022.65,2023.55],"y":[1,1,3,3],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type" ...

# %%
elto_lista_mod = lista_modelos.iloc[1]
model_name = elto_lista_mod['modelo']
carrera =elto_lista_mod['carrera']

df_datos = df[df['carrera'] == elto_lista_mod['carrera']]

# cargar el modelo
modelo = BERTopic.load(model_name,embedding_model)

# mostrar resultados en forma visual
mostrar_resultados_por_carrera(carrera, df_datos, modelo)
# Out:
# Resultados del modelado de tópicos - Licenciatura en Recursos Humanos
# ------------------------------------------------------------------------
#
# Tópicos
# -----------
#    Topic  Count                                               Name  \
# 0      0     46        0_recursos humanos_empresa_proceso_personal
# 1      1     27  1_investigación_recursos humanos_gestión_emple...
# 2      2     12  2_clima_clima organizacional_clima laboral_pro...
# 3      3     25       3_empleados_habilidades_motivación_liderazgo
#
#                                           CustomName  \
# 0  Gestión Estratégica de Recursos Humanos en Emp...
# 1  Gestión de Recursos Humanos: Salud, Estrés y R...
# 2  Satisfacción Laboral y su Impacto en el Desemp...
# 3  Desarrollo de Habilidades y Motivación en el C...
#
#                                       Representation  Representative_Docs
# 0  [recursos humanos, empresa, proceso, personal,...                  NaN
# 1  [investigación, recursos humanos, gestión, emp...                  NaN
# 2  [clima, clima organizacional, clima laboral, p...                  NaN
# 3  [empleados, habilidades, motivación, liderazgo...                  NaN
# Tópicos y probabilidades
# ------------------------
#                Topic0_word  Topic0_prob       Topic1_word  Topic1_prob  \
# 0         recursos humanos     0.025781     investigación     0.022530
# 1                  empresa     0.022494  recursos humanos     0.016107
# 2                  proceso     0.020299           gestión     0.015943
# 3                 personal     0.013895         empleados     0.015593
# 4               desarrollo     0.011623          relación     0.014035
# 5  reclutamiento selección     0.011595             salud     0.013554
# 6                    salta     0.011358         desempeño     0.012816
# 7             herramientas     0.009040            social     0.012662
# 8                empleados     0.008670       teletrabajo     0.012424
# 9                    horas     0.008402            estrés     0.011629
#
#             Topic2_word  Topic2_prob       Topic3_word  Topic3_prob
# 0                 clima     0.060877         empleados     0.015622
# 1  clima organizacional     0.039442       habilidades     0.015617
# 2         clima laboral     0.025560        motivación     0.014641
# 3         productividad     0.024205         liderazgo     0.014342
# 4  evaluación desempeño     0.019256           calidad     0.014228
# 5             empleados     0.018226       diferencias     0.012623
# 6  satisfacción laboral     0.015777  recursos humanos     0.011736
# 7      recursos humanos     0.014453    organizaciones     0.010822
# 8     desempeño laboral     0.014132         objetivos     0.009827
# 9               cultura     0.013754           capital     0.009761
# Ranking de palabras en cada tópico
# ----------------------------------
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d7e54871-6e7f-4f20-8389-b4f81766e118" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7e54871-6e7f-4f20-8389-b4f81766e118")) {                    Plotly.newPlot(                        "d7e54871-6e7f-4f20-8389-b4f81766e118",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.011622951599393213,0.013894545974002978,0.020298737793479366,0.02249441047338494,0.025780736931327892],"y":["desarrollo  ","personal  ","proceso  ","empresa  ","recursos humanos  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.014034557190891814,0.015593121118225847,0.015942991144394375,0.016106998302969733,0.022530432732028212],"y":["relación  ","empleados  ","gestión  ","recursos humanos  ","investigación  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.019255785775433982,0.024204906534773238,0.0255602667690235,0.03944233036326994,0.06087664093371619],"y":["evaluación desempeño  ","productividad  ","clima laboral  ","clima organizacional  ","clima  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.014228119780718272,0.014341992328066554,0.014640928991891013,0.015616990924683745,0.015621832444166237],"y":["calidad  ","liderazgo  ","motivación  ","habilidades  ","empleados  "],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type" ...
# Distribución de clusters
# ------------------------
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fd9eb18c-3b70-402b-9e05-c1f781edb4d9" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd9eb18c-3b70-402b-9e05-c1f781edb4d9")) {                    Plotly.newPlot(                        "fd9eb18c-3b70-402b-9e05-c1f781edb4d9",                        [{"customdata":[[0,"recursos humanos | empresa | proceso | personal | desarrollo",46],[1,"investigación | recursos humanos | gestión | empleados | relación",27],[2,"clima | clima organizacional | clima laboral | productividad | evaluación desempeño",12],[3,"empleados | habilidades | motivación | liderazgo | calidad",25]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[46,27,12,25],"sizemode":"area","sizeref":0.02875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[23.816517,24.665895,24.143969,26.418064],"xaxis":"x","y":[5.543534,5.4225154,6.4521804,6.8015537],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolo ...
# Jerarquía de clusters
# ---------------------
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fce4cb90-2479-4259-8b6c-0e1510ac21ea" class="plotly-graph-div" style="height:260px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fce4cb90-2479-4259-8b6c-0e1510ac21ea")) {                    Plotly.newPlot(                        "fce4cb90-2479-4259-8b6c-0e1510ac21ea",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.5471598536730016,0.5471598536730016,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.5993916781060756,0.5993916781060756,0.5471598536730016],"xaxis":"x","y":[-15.0,-15.0,-30.0,-30.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.6963157752503583,0.6963157752503583,0.5993916781060756],"xaxis":"x","y":[-5.0,-5.0,-22.5,-22.5],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":260,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["2_clima_clima organizaciona...","1_investigación_recursos hu...","0_recursos humanos_empresa_...","3_empleados_habilidades_mot..."],"tickvals":[-5.0,-15.0,-25.0,-35.0],"type":"linear","zeroline":false,"range":[-40.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666666 ...
# Evolución de tópicos por años
# ---------------------------
# 10it [00:00, 29.05it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="486c033c-9900-4d36-81de-29a0c31fd66d" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("486c033c-9900-4d36-81de-29a0c31fd66d")) {                    Plotly.newPlot(                        "486c033c-9900-4d36-81de-29a0c31fd66d",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: trabajo, empresa, proceso, reclutamiento, reclutamiento selección","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: empresa, recursos, recursos humanos, humanos, comunicación","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: humano, retención, talento, arca continental, arca","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: recursos, recursos humanos, humanos, empresa, calidad","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: trabajo, recursos, empresa, puesto, recursos humanos","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: recursos, recursos humanos, humanos, proceso, empresa","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: práctica, práctica profesional, memoria, profesional, industrial cervecera","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: proceso, recursos, recursos humanos, humanos, trabajadoras","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: memoria práctica, práctica profesional, memoria, práctica, profesional"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_recursos humanos_empresa_proceso_perso...","x":[2015.9,2016.8,2017.7,2018.6,2019.95,2020.85,2021.75,2022.65,2023.55],"y":[2,5,2,8,5,14,2,7,1],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: desempeño, empleados, sistema, evaluación, puede","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: personal, sanatorio santa, santa, sanatorio, privada salud","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: trabajo, laboral, rotación, personal, investigación","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: trabajo, laboral, investigación, rotación, ausentismo","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: laboral, trabajo, recursos, estrés, medidas","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: trabajo, teletrabajo, pandemia, social, vida","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: trabajo, laboral, salud, calidad vida, vida","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: laboral, trabajo, condiciones, empresa, provincia"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"1_investigación_recursos humanos_gestión...","x":[2014.991,2015.9,2018.6,2019.95,2020.85,2021.75,2022.65,2023.55],"y":[1,1,7,5,7,1,3,2],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: clima, organizacional, clima organizacional, sanatorio, organizacional sanatorio","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: clima, laboral, cada, clima laboral, empleados cada","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: desempeño, evaluación, laboral, evaluación desempeño, clima","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: inducción, proceso inducción, proceso, evaluación desempeño, desempeño","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: clima, organizacional, clima organizacional, laboral, desempeño","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: laboral, organizacional, clima, empresa, productividad"],"marker":{"color":"#009E73"},"mode":"lines","name":"2_clima_clima organizacional_clima labor...","x":[2017.7,2018.6,2019.95,2020.85,2021.75,2022.65],"y":[1,2,2,1,2, ...

# %%
elto_lista_mod = lista_modelos.iloc[2]
model_name = elto_lista_mod['modelo']
carrera =elto_lista_mod['carrera']

df_datos = df[df['carrera'] == elto_lista_mod['carrera']]

# cargar el modelo
modelo = BERTopic.load(model_name, embedding_model)

# mostrar resultados en forma visual
mostrar_resultados_por_carrera(carrera, df_datos, modelo)
# Out:
# Resultados del modelado de tópicos - Licenciatura en Comunicaciones Sociales
# -------------------------------------------------------------------------------
#
# Tópicos
# -----------
#    Topic  Count                                               Name  \
# 0      0     20   0_redes sociales_comunicación_trabajo_periodismo
# 1      1     22       1_comunicación_investigación_público_cambios
# 2      2     15  2_influencers_redes sociales_estrategias_insta...
# 3      3     46       3_análisis_trabajo_estrategias_institucional
#
#                                           CustomName  \
# 0  Comunicación Social: Periodismo y Participació...
# 1  Comunicación Social: Identidad y Estrategias e...
# 2  Estrategias de Influencia Digital: Emprendimie...
# 3  Comunicación Estratégica: Gestión Instituciona...
#
#                                       Representation  Representative_Docs
# 0  [redes sociales, comunicación, trabajo, period...                  NaN
# 1  [comunicación, investigación, público, cambios...                  NaN
# 2  [influencers, redes sociales, estrategias, ins...                  NaN
# 3  [análisis, trabajo, estrategias, institucional...                  NaN
# Tópicos y probabilidades
# ------------------------
#            Topic0_word  Topic0_prob    Topic1_word  Topic1_prob  \
# 0       redes sociales     0.023206   comunicación     0.026513
# 1         comunicación     0.020800  investigación     0.021678
# 2              trabajo     0.017399        público     0.013431
# 3           periodismo     0.015501        cambios     0.012551
# 4             sociedad     0.013475   ciudad salta     0.012059
# 5  medios comunicación     0.012387      canciones     0.009792
# 6          periodistas     0.011580      identidad     0.009535
# 7            cobertura     0.010860    estrategias     0.009289
# 8            provincia     0.010822         social     0.008893
# 9               juicio     0.009521    videojuegos     0.008585
#
#       Topic2_word  Topic2_prob               Topic3_word  Topic3_prob
# 0     influencers     0.026869                  análisis     0.016412
# 1  redes sociales     0.025933                   trabajo     0.015723
# 2     estrategias     0.024179               estrategias     0.015200
# 3       instagram     0.023487             institucional     0.010658
# 4         mercado     0.016535              ciudad salta     0.010119
# 5        usuarios     0.016149                   campaña     0.009828
# 6        branding     0.015929  estrategias comunicación     0.009795
# 7           blogs     0.013965                     salud     0.009747
# 8         mujeres     0.013383                    social     0.008291
# 9      red social     0.012932                   alumnos     0.008156
# Ranking de palabras en cada tópico
# ----------------------------------
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bc859cb1-2aca-49ea-ab64-7f331a9fccc0" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc859cb1-2aca-49ea-ab64-7f331a9fccc0")) {                    Plotly.newPlot(                        "bc859cb1-2aca-49ea-ab64-7f331a9fccc0",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.013475412154318394,0.015500702652993834,0.01739918636288882,0.020799965199527284,0.02320569203330022],"y":["sociedad  ","periodismo  ","trabajo  ","comunicación  ","redes sociales  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.012058529129324978,0.012551422816684999,0.013431023282001684,0.02167823000704728,0.026513169617113436],"y":["ciudad salta  ","cambios  ","público  ","investigación  ","comunicación  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.016534844277904203,0.023486857447067844,0.024179179664748342,0.025932634213183543,0.026869121951594327],"y":["mercado  ","instagram  ","estrategias  ","redes sociales  ","influencers  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.010118619426175144,0.0106582392923596,0.015200045120772764,0.015722985096551425,0.016411630972956916],"y":["ciudad salta  ","institucional  ","estrategias  ","trabajo  ","análisis  "],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d ...
# Distribución de clusters
# ------------------------
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="16bcc1a3-3f93-4583-90a8-50fe3d96df16" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16bcc1a3-3f93-4583-90a8-50fe3d96df16")) {                    Plotly.newPlot(                        "16bcc1a3-3f93-4583-90a8-50fe3d96df16",                        [{"customdata":[[0,"redes sociales | comunicación | trabajo | periodismo | sociedad",20],[1,"comunicación | investigación | público | cambios | ciudad salta",22],[2,"influencers | redes sociales | estrategias | instagram | mercado",15],[3,"análisis | trabajo | estrategias | institucional | ciudad salta",46]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[20,22,15,46],"sizemode":"area","sizeref":0.02875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-1.2350501,-1.4081875,-0.7820108,-0.7923398],"xaxis":"x","y":[10.6945505,11.712255,10.126667,12.158919],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb ...
# Jerarquía de clusters
# ---------------------
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="15f1f1da-881a-44aa-af29-178b794bf1a3" class="plotly-graph-div" style="height:260px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15f1f1da-881a-44aa-af29-178b794bf1a3")) {                    Plotly.newPlot(                        "15f1f1da-881a-44aa-af29-178b794bf1a3",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.618330082595959,0.618330082595959,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.6938207845414215,0.6938207845414215,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.618330082595959,0.7291075282377999,0.7291075282377999,0.6938207845414215],"xaxis":"x","y":[-10.0,-10.0,-30.0,-30.0],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":260,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["1_comunicación_investigació...","3_análisis_trabajo_estrateg...","0_redes sociales_comunicaci...","2_influencers_redes sociale..."],"tickvals":[-5.0,-15.0,-25.0,-35.0],"type":"linear","zeroline":false,"range":[-40.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666666666 ...
# Evolución de tópicos por años
# ---------------------------
# 9it [00:00, 27.19it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2467f1b1-5e17-48e6-bd7e-3e7c62b1fa32" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2467f1b1-5e17-48e6-bd7e-3e7c62b1fa32")) {                    Plotly.newPlot(                        "2467f1b1-5e17-48e6-bd7e-3e7c62b1fa32",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: derecho, juicio, diario, cobertura, intimidad","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: medios, análisis, medios comunicación, comunicación, salta","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: sociales, salta, redes, redes sociales, información","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: diario, salta, análisis, humor, tribuno","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: redes sociales, redes, sociales, personas, mensaje","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: redes, medios, información, sociales, redes sociales","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: noticias, personas, sociedad, medios, salta"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_redes sociales_comunicación_trabajo_pe...","x":[2015.992,2016.8,2018.8,2019.6,2020.8,2022.8,2023.6],"y":[3,2,6,3,2,2,2],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: banda, identidad, grotesco, identidad imagen, cuerpos","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: comunicación, cuerpo, investigación, salta, nuevas","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: juegos, usuarios, museo, callejeros, aplicaciones juegos","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: drag, patrimonio, acústico, comunicación, relevamiento","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: danza, comunicación, investigación, público, videojuegos","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: visual supermercado, supermercado, identidad visual, visual, identidad","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: comunicación, nuevas, sector, objetivos, investigación"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"1_comunicación_investigación_público_cam...","x":[2015.992,2017.6,2018.8,2019.6,2021.6,2022.8,2023.6],"y":[2,6,4,2,5,1,2],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: moda, mujer, blogs, clientes, atelier","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: influencers, comunicación, sociales, marca, branding","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: posverdad, instagram, influencers, nadal, discursos mediáticos","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: marca, redes, contenido, redes sociales, sociales","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: marca, estrategias, instagram, redes, influencers"],"marker":{"color":"#009E73"},"mode":"lines","name":"2_influencers_redes sociales_estrategias...","x":[2015.992,2018.8,2021.6,2022.8,2023.6],"y":[3,5,1,2,4],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: salesiano, metáforas, metáforas fútbol, juvenil salesiano, comunicación","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: comunicación, campaña, salta, tic, investigación","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: comunicación, salta, investigación, estrategias, año","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: comunicación, salta, investigación, imagen, empresa","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: comunicación, empresa, educac ...

# %% [markdown]
# ## Attributes
#
# There are a number of attributes that you can access after having trained your BERTopic model:
#
#
# | Attribute | Description |
# |------------------------|---------------------------------------------------------------------------------------------|
# | topics_               | The topics that are generated for each document after training or updating the topic model. |
# | probabilities_ | The probabilities that are generated for each document if HDBSCAN is used. |
# | topic_sizes_           | The size of each topic                                                                      |
# | topic_mapper_          | A class for tracking topics and their mappings anytime they are merged/reduced.             |
# | topic_representations_ | The top *n* terms per topic and their respective c-TF-IDF values.                             |
# | c_tf_idf_              | The topic-term matrix as calculated through c-TF-IDF.                                       |
# | topic_labels_          | The default labels for each topic.                                                          |
# | custom_labels_         | Custom labels for each topic as generated through `.set_topic_labels`.                                                               |
# | topic_embeddings_      | The embeddings for each topic if `embedding_model` was used.                                                              |
# | representative_docs_   | The representative documents for each topic if HDBSCAN is used.                                                |
#
# For example, to access the predicted topics for the first 10 documents, we simply run the following:

# %%
# from bertopic.representation import MaximalMarginalRelevance

# #Mejorar la representación predeterminada. CountVectorizer elimina palabras vacías e ignora las palabras poco frecuentes.
# #Considera los tokens con una o dos palabras (ngramas).
# vectorizer_model = CountVectorizer(stop_words=stopwords, ngram_range=(1, 2))

# #Obtener embeddings
# embedding_model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

#   #Para reducir esta redundancia y mejorar la diversidad de palabras clave, el algoritmo MMR considera la similitud de las palabras clave o frases clave con el documento,
#     #así la selección de palabras clave maximiza su diversidad dentro del documento.
# representation_model = MaximalMarginalRelevance(diversity=0.5)
# #   λ = 1.0: Relevancia pura (búsqueda vectorial regular)
# # λ = 0,5: Enfoque equilibrado
# # λ = 0,0: Diversidad pura

# # función para entrenar el modelo a partir de un conjunto de documentos
# def train_model(docs, carrera, df_carr):
#   #configuración inicial
#   min_cluster_size, n_neighbors, outliers = config_model(len(docs))

#   #embeddings
#   embeddings = embedding_model.encode(docs, show_progress_bar=True)

#  # HDBSCAN: min_cluster_size controla la cantidad de temas que se crearán. Un número grande generará menos temas y un número pequeño generará más temas.
#   hdbscan_model = HDBSCAN(min_cluster_size=min_cluster_size, metric='euclidean', cluster_selection_epsilon=0.05, min_samples=3, prediction_data=True)
#  # cluster_selection_epsilon=0.05,  # ↓ Menor valor para evitar unir clusters cercanos
#  # cluster_selection_method='eom', , prediction_data=True
#  #min_samples=3,             # ↑ Mayor valor para clusters más densos

#     # UMAP reduce la dimensionalidad
#   umap_model = UMAP(n_neighbors=n_neighbors, min_dist=0.2, metric='cosine', random_state=42)
#     #n_neighbors=15 n_neighbors
#     #n_components=10 ↑ Mayor dimensionalidad para separar clusters


#   # Definición del modelo
#   topic_model = BERTopic(
#       # Pipeline models
#       embedding_model=embedding_model,
#       umap_model=umap_model,
#       hdbscan_model=hdbscan_model,
      vectorizer_model=vectorizer_model,
      representation_model=representation_model,

      nr_topics=5,  # FORZAR max de tópicos (intenta reducir a 5 si hay más)

      calculate_probabilities=True,
      language="multilingual",
      # Hyperparameters
      #top_n_words=10,
      verbose=True
    )

# Train model
  topics, probs = topic_model.fit_transform(docs, embeddings=embeddings)

  # # si hay muchos outliers, ajustar modelo
  if (topics.count(-1) > outliers):
     print(f"  Reajustando modelo ...outliers: {topics.count(-1)}")
     # reducción de outliers
     new_topics = topic_model.reduce_outliers(docs, topics, probabilities=probs, strategy="probabilities") #strategy xq en topic_model se calculó las probab

  #   #topic_model.update_topics(docs, topics=new_topics)  #toma stopwords
  #   #topic_model.update_topics(docs, vectorizer_model=vectorizer_model, embedding_model=embedding_model)
  #   #topic_model.update_topics(docs, vectorizer_model=vectorizer_model)
     #topic_model.update_topics(docs, topics=new_topics,vectorizer_model=vectorizer_model)
     topic_model.update_topics(docs, topics=new_topics,vectorizer_model=vectorizer_model, representation_model=representation_model)

  #Generar etiquetas personalizadas
  docs_per_topic = topic_model.get_representative_docs()

  # Get the active topic IDs from the model's final state after reduction
  #active_topic_ids = topic_model.get_topic_info()['Topic'].tolist()

  #custom_labels = generar_labels(topic_model, docs_per_topic, active_topic_ids, carrera)

  # Asignar las etiquetas al modelo
  #topic_model.set_topic_labels(custom_labels)

  df_carr['topic'] = topics

  # Extract the probability of the assigned topic from the 2D 'probs' array
  assigned_probabilities = []
  for doc_idx, topic_id in enumerate(topics):
      if topic_id == -1:
          assigned_probabilities.append(0.0)  # Assign 0 for outlier topic, or consider a different approach
      else:
          # Ensure topic_id maps to a valid column index in probs
          if topic_id < probs.shape[1]:
              assigned_probabilities.append(probs[doc_idx, topic_id])
          else:
              assigned_probabilities.append(0.0) # Fallback if topic_id is out of bounds

  df_carr['topic_probability'] = assigned_probabilities

  # Add Representative_document column
  representative_docs_set = set()
  for topic_id, docs_list in docs_per_topic.items():
      for doc_text in docs_list:
          representative_docs_set.add((topic_id, doc_text))

  df_carr['Representative_document'] = df_carr.apply(
      lambda row: (row['topic'], row['texto_limpio']) in representative_docs_set,
      axis=1
  )

  # Print the number of valid topics found
  # num_valid_topics = len(topic_model.get_topic_info()) - 1
  # print(f"  Número de tópicos válidos encontrados: {num_valid_topics}")

  return topic_model , df_carr
# Out:
#   File "<tokenize>", line 53
#     )
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
No va
from IPython.display import display

def mostrar_resultados_por_carrera(carrera, df, model):
  print(f"Resultados del modelado de tópicos - {carrera}")
  print("-"*(len(carrera)+40))

  df_carrera = df[df['carrera']==carrera]

    # Imprimo resulados
  print("\nTópicos")
  print("-----------")
  freq = model.get_topic_info()
  display(freq)
  print()

  print("\nTópicos y probabilidades")
  print("------------------------")
  # mostrar todos los tópicos cons las keys
  df_topics = pd.DataFrame()   #auxiliar
  all_topics = model.get_topics()
  for topico in all_topics:
    df_topic_words_temp = pd.DataFrame(model.get_topic(topico))
    df_topic_words_temp.columns = [f'Topic{topico}_word', f'Topic{topico}_prob']
    df_topics = pd.concat([df_topics, df_topic_words_temp], axis=1)

  display(df_topics)

  print('\nRanking de palabras en cada tópico')
  print('----------------------------------')
 # barchart de ranking de palabras por tópico (se inclyen 5 keys por tópico por claridad)
  fig1 = model.visualize_barchart(top_n_topics=len(model.get_topics()), n_words=5)
  display(fig1)

  if (len(all_topics)-1) > 2:
    print('\nDistribución de clusters')
    print('------------------------')
    # interactivo distribución/distancia entre tópicos
    try:
      fig2 = model.visualize_topics()
      display(fig2)
    except TypeError as e:
      print(f"  Error al visualizar la distribución de clusters (visualize_topics): {e}")
      print("  Esto puede ocurrir con un número muy pequeño de tópicos. Se omitirá esta visualización.")

  print('\nJerarquía de clusters')
  print('---------------------')

  # jerarquia de clusters
  fig3 = model.visualize_hierarchy(top_n_topics=50)
  display(fig3)

  print('\nEvolución de tópicos por años')
  print('---------------------------')
  # Evolución de tópicos por años
  timestamps = df_carrera['anio'].tolist()
  topics_over_time = model.topics_over_time(df_carrera['texto_limpio'], timestamps, nr_bins=20)
  fig4 =  model.visualize_topics_over_time(topics_over_time, top_n_topics=10)
  display(fig4)

# %% [markdown]
# **Reasoning**:
# After updating the `mostrar_resultados_por_carrera` function to correctly display the Plotly figures, I need to re-run the cell that calls this function for 'Licenciatura en Psicología' to see the visualizations.

# %%
elto_lista_mod = lista_modelos.iloc[0]
model_name = elto_lista_mod['modelo']
carrera =elto_lista_mod['carrera']

df_datos = df[df['carrera'] == elto_lista_mod['carrera']]

# cargar el modelo
modelo = BERTopic.load(model_name, embedding_model)

# mostrar resultados en forma visual
mostrar_resultados_por_carrera(carrera, df_datos, modelo)

# %%
FINAL ...
