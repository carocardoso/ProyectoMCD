# %% [markdown]
# Si instalás solo BERTopic sin “extras”, podés evitar parte de ese “bloat”. Por ejemplo, la documentación menciona una instalación ligera con pip install --no-deps bertopic.

# %%
#pip install --no-deps bertopic

# %%
import os
from bertopic import BERTopic
#from .autonotebook import tqdm as notebook_tqdm

# %%
directorio_actual = os.getcwd()

modelo_name =  "..\modelos\Ingeniería_Industrial_topicmodel.zip"  # directorio_actual+"\modelos\Ingeniería_Industrial_topicmodel.zip"
print(modelo_name)
my_model = BERTopic.load(modelo_name, embedding_model='paraphrase-multilingual-MiniLM-L12-v2')
# Out:
# ..\modelos\Ingeniería_Industrial_topicmodel.zip
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\envs\myenv\lib\pickle.py:1244, in _Unpickler.load_persid(self)
#    1243 try:
# -> 1244     pid = self.readline()[:-1].decode("ascii")
#    1245 except UnicodeDecodeError:
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe2 in position 13: ordinal not in range(128)
#
# During handling of the above exception, another exception occurred:
#
# UnpicklingError                           Traceback (most recent call last)
# Cell In[9], line 5
#       3 modelo_name =  "..\modelos\Ingeniería_Industrial_topicmodel.zip"  # directorio_actual+"\modelos\Ingeniería_Industrial_topicmodel.zip"
#       4 print(modelo_name)
# ----> 5 my_model = BERTopic.load(modelo_name, embedding_model='paraphrase-multilingual-MiniLM-L12-v2')
#
# ...

# %%
loaded_model_freq = loaded_model.get_topic_info()
print(loaded_model_freq.head())

# %%
# from bertopic import BERTopic

# # Choose one of the saved models to load
# # For example, loading the model for 'Ingeniería Industrial'
# loaded_model = BERTopic.load("Ingeniería_Industrial_topicmodel.zip")

# print("Loaded model topic information for Ingeniería Industrial:")
# # Display the frequent topics from the loaded model
# # -1 typically refers to outliers and can often be ignored
# loaded_model_freq = loaded_model.get_topic_info()
# print(loaded_model_freq.head())

# print("\nExample of a frequent topic from the loaded model:")
# # Display the most frequent topic (Topic 0) words and their scores
# print(loaded_model.get_topic(0))
